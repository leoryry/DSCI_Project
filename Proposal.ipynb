# %%
DSCI Project Proposal

# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.0.1”
# Warning message:
# “package ‘tibble’ was built under R version 4.0.2”
# Warning message:
# “package ‘tidyr’ was built under R version 4.0.2”
# Warning message:
# “package ‘dplyr’ was built under R version 4.0.2”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
Introduction:
Question:

# %%
# Out:
# Parsed with column specification:
# cols(
#   `15.26` = col_double(),
#   `14.84` = col_double(),
#   `0.871` = col_double(),
#   `5.763` = col_double(),
#   `3.312` = col_double(),
#   `2.221` = col_double(),
#   `5.22` = col_double(),
#   `1` = col_double()
# )
#
# Warning message:
# “11 parsing failures.
# row col  expected     actual                file
#   7  -- 8 columns 10 columns 'seeds_dataset.txt'
#  35  -- 8 columns 10 columns 'seeds_dataset.txt'
#  60  -- 8 columns 9 columns  'seeds_dataset.txt'
#  68  -- 8 columns 9 columns  'seeds_dataset.txt'
# 106  -- 8 columns 9 columns  'seeds_dataset.txt'
# ... ... ......... .......... ...................
# See problems(...) for more details.
# ”
#     area  perimeter compactness length_kernel width_kernel
# 1   14.88 14.57     0.8811      5.554         3.333
# 2   14.29 14.09     0.9050      5.291         3.337
# 3   13.84 13.94     0.8955      5.324         3.379
# 4   16.14 14.99     0.9034      5.658         3.562
# ...

# %%
hello

# %%
student <- read
